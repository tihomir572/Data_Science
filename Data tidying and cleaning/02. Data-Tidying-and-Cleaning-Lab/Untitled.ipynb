# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv('titanic_original.csv')

# %%
titanic[titanic['body'].isnull()]
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1.0       1.0                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1303     3.0       0.0                            Yousseff, Mr. Gerious
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
iris = pd.read_csv('iris.data',header = None)

# %%
iris.columns = ["sepal_length", "sepal_width", "petal_length", "petal_width", "iris_name"]

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width       iris_name
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# my_list = []
# for index in range(150):
#     Iris = iris[0][index].split(',')
#     my_list.append(Iris[-1].split('-')[-1])
# set(my_list)

# %%
iris.iris_name.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris = iris[iris['sepal_length'] <= 10] 
iris = iris[iris['sepal_length'] >= 4.5] 
mean=iris['petal_length'].mean()
print(f'{mean:.2f}')
# Out:
# 3.83

# %%
red_wine = pd.read_csv('winequality-red.csv', sep=";")
corr_red = red_wine['alcohol'].corr(red_wine['quality'])
print(f'{corr_red:.2f}')
# Out:
# 0.48

# %%
white_wine = pd.read_csv('winequality-white.csv', sep=";")
corr_white = white_wine['alcohol'].corr(white_wine['quality'])
print(f'{corr_white:.2f}')
# Out:
# 0.44

# %%
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...
