# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import skimage.io
from skimage.morphology import binary_opening
from skimage.morphology import square
import re
from collections import Counter
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tihomir111\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
page1 = skimage.io.imread("hamburger.jpg")

# %%
page1
# Out:
# array([[[39, 35, 50],
#         [39, 37, 51],
#         [40, 39, 53],
#         ...,
#         [10, 14, 23],
#         [11, 16, 22],
#         [11, 16, 22]],
#
#        [[39, 35, 50],
#         [40, 38, 52],
#         [40, 39, 53],
#         ...,
#         [11, 15, 24],
#         [11, 16, 22],
#         [11, 16, 22]],
#
#        [[40, 36, 51],
#         [40, 38, 52],
#         [40, 39, 53],
#         ...,
#         [11, 15, 24],
#         [10, 15, 21],
#         [10, 15, 21]],
#
#        ...,
#
#        [[35, 31, 20],
#         [40, 36, 25],
#         [44, 40, 29],
#         ...,
#         [12,  7,  4],
#         [13,  9,  6],
#         [12,  8,  5]],
#
#        [[22, 18,  7],
#         [27, 23, 12],
#         [34, 30, 19],
#         ...,
#         [20, 15, 12],
#         [16, 12,  9],
#         [15, 11,  8]],
#
#        [[24, 21, 14],
#         [28, 25, 18],
#         [27, 24, 17],
#         ...,
#         [25, 23, 24],
#         [22, 20, 23],
#         [23, 21, 24]]], dtype=uint8)

# %%
red_images = page1[:,:,0]
green_images = page1[:,:,1]
blue_images = page1[:,:,2]

# %%
plt.imshow(red_images)

# %%
plt.imshow(green_images)

# %%
plt.imshow(blue_images,cmap = "gray")

# %%
plt.imshow(binary_opening(blue_images),cmap = "gray")

# %%
blue_images.shape
# Out:
# (417, 626)

# %%
a=binary_opening(blue_images) ==1
len(a)
# Out:
# 417

# %%
print(page1.nbytes)
# Out:
# 783126

# %%
blue_chanel_binary = binary_opening(image=blue_images, selem = square(3))
# Out:
# C:\Users\Tihomir111\AppData\Local\Temp\ipykernel_3228\4088128043.py:1: FutureWarning: `selem` is a deprecated argument name for `binary_opening`. It will be removed in version 1.0. Please use `footprint` instead.
#   blue_chanel_binary = binary_opening(image=blue_images, selem = square(3))

# %%
blue_chanel_binary
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
unique, counts = np.unique(blue_chanel_binary, return_counts=True)

# %%
counts
# Out:
# array([ 78052, 182990], dtype=int64)

# %%
text = ""
with open("1342-0.txt", "r", encoding = "utf-8") as f:
    text = f.read()
text = Counter(re.split('\W',text.lower()))

# %%
# stop = set(stopwords.words("english"))
# text=[w for w in text.lower().split() if w not in stop]

# %%
text.most_common(100)
# Out:
# [('', 94919),
#  ('the', 4521),
#  ('to', 4245),
#  ('of', 3734),
#  ('and', 3657),
#  ('her', 2202),
#  ('i', 2048),
#  ('a', 2006),
#  ('in', 1939),
#  ('was', 1846),
#  ('she', 1691),
#  ('that', 1555),
#  ('it', 1550),
#  ('not', 1449),
#  ('you', 1401),
#  ('he', 1328),
#  ('his', 1257),
#  ('be', 1256),
#  ('as', 1193),
#  ('had', 1172),
#  ('with', 1098),
#  ('for', 1084),
#  ('but', 1006),
#  ('is', 879),
#  ('have', 846),
#  ('at', 802),
#  ('mr', 784),
#  ('him', 752),
#  ('on', 729),
#  ('my', 702),
#  ('s', 664),
#  ('by', 663),
#  ('all', 640),
#  ('elizabeth', 634),
#  ('they', 599),
#  ('so', 593),
#  ('were', 565),
#  ('which', 546),
#  ('could', 526),
#  ('been', 513),
#  ('from', 508),
#  ('no', 501),
#  ('very', 490),
#  ('this', 488),
#  ('what', 478),
#  ('would', 467),
#  ('your', 446),
#  ('their', 439),
#  ('them', 429),
#  ('me', 427),
#  ('darcy', 417),
#  ('will', 415),
#  ('said', 402),
#  ('such', 391),
#  ('or', 376),
#  ('if', 372),
#  ('when', 372),
# ...

# %%
# # a=[x for x in text.split() if text == 'pride']
# text=text.split()

# %%
# [x for x in text if text =='pride']

# %%
text

# %%
# counter = 0

# for word in text.lower():
#     if word == 'pride':
#         counter +=1
# counter

# %%
counter = Counter(text)
